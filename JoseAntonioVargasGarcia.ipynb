# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### I apologize because I wasn't able to open IBM Watson Studio.

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __JOSE ANTONIO VARGAS GARCÍA__
#
# __I'D LIKE TO BECOME A DATA SCIENTIST__

# %% [markdown]
# _I am interested in data science because I'd like to change the way of my live. Don't get me wrong, I love my job but sometimes I think I could have studied harder when I was young and now I would be a totally different person."_

# %% [markdown]
#  It must be executed and must display an output. 2357+2357=4714

# %%
2357+2357
# Out:
# 4714

# %% [markdown]
# https://hub.docker.com/r/continuumio/anaconda3
#
# ![Captura (89).png](attachment:89a7997f-d23e-4221-aed3-c32dcd2affdc.png)
# ![Captura (90).png](attachment:3ca8eb82-a4d0-49c4-8a7c-52f176c09e32.png)
